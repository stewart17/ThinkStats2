# %% [markdown]
# # Assignment 3.2 - ( 1.1,1.2,2.1&2.4)
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
# Setup to load pre dataframe
from __future__ import print_function, division

import nsfg

# %% [markdown]
# ## Question 1-1

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN  ...           0           0        0
# 1       NaN       1.0       NaN  ...           0           0        0
# 2       NaN       3.0       5.0  ...           0           0        0
# 3       NaN       1.0       NaN  ...           0           0        0
# 4       NaN       1.0       NaN  ...           0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %%
#Selecting birthord column using dot notation on preg dataframe, then using value_counts to print value counts, 
#followed by sort_index to print in ordered way.
#Output matches with results published in the codebook
preg.birthord.value_counts().sort_index()
# Out:
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %%
# Compare to results published in the codebook

# %% [markdown]
# ![Capture.JPG](attachment:Capture.JPG)

# %%
# Print just the count of null values in birthord column
print(f'Number of null vlaues in birth order {preg.birthord.isnull().sum()}')
# Out:
# Number of null vlaues in birth order 4445

# %%
#Select prglngth column, print the value counts, and compare to results published in the codebook 

preg.prglngth.value_counts().sort_index()
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %%
# Variable prglngth pubplished result in codebook

# %% [markdown]
# ![prglngth.JPG](attachment:prglngth.JPG)

# %%
#To match the codebook output, filter the dataframe in three groups and then count non null values of prglngth field.
#Output matches with what is given in the codebook
prglngth0to13 = preg[(preg.prglngth >= 0) & (preg.prglngth <= 13)].prglngth.count()
prglngth14to26 = preg[(preg.prglngth >= 14) & (preg.prglngth <= 26)].prglngth.count()
prglngth27to50 = preg[(preg.prglngth >= 27) & (preg.prglngth <= 50)].prglngth.count()

print(f'---------------------------------\n13 WEEKS OR LESS {prglngth0to13}')
print(f'14-26 WEEKS {prglngth14to26}')
print(f'27 WEEKS OR LONGER {prglngth27to50}')
# Out:
# ---------------------------------
# 13 WEEKS OR LESS 3522
# 14-26 WEEKS 793
# 27 WEEKS OR LONGER 9278

# %% [markdown]
# To compute the mean of a column, you can invoke the mean method on a Series. For example, here is the mean birthweight in pounds:

# %%
#Calculate mean of totalwgt_lb column
preg.totalwgt_lb.mean()
# Out:
# 7.265628457623368

# %% [markdown]
# Create a new column named totalwgt_kg that contains birth weight in kilograms. Compute its mean. Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %%
#Add totalwgt_kg column to preg dataframe using dictionary syntax
preg['totalwgt_kg'] = preg.totalwgt_lb / 2.205

#Find and print mean of add column
print(f'Mean of new column totalwgt_kg is {(preg.totalwgt_kg.mean())}')
# Out:
# Mean of new column totalwgt_kg is 3.2950695952940463

# %% [markdown]
# nsfg.py also provides ReadFemResp, which reads the female respondents file and returns a DataFrame:

# %% [markdown]
# preg.outcome.value_counts().sort_index()

# %%
resp = nsfg.ReadFemResp()
resp.head()
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
# 1    5012        1         5         1            5          5.0     42
# 2   11586        1         5         1            5          5.0     43
# 3    6794        5         5         4            1          5.0     15
# 4     616        1         5         4            1          5.0     20
#
#    age_r  cmbirth  agescrn  ...  pubassis_i      basewgt  adj_mod_basewgt  \
# 0     27      902       27  ...           0  3247.916977      5123.759559
# 1     42      718       42  ...           0  2335.279149      2846.799490
# 2     43      708       43  ...           0  2335.279149      2846.799490
# 3     15     1042       15  ...           0  3783.152221      5071.464231
# 4     20      991       20  ...           0  5341.329968      6437.335772
#
#       finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime   intvlngth
# ...

# %% [markdown]
# Select the age_r column from resp and print the value counts. How old are the youngest and oldest respondents?

# %%
#Printing value counts of age_r column and sorting it
print(resp.age_r.value_counts().sort_index())

#Print youngest respondent
print(f'\n-----------------\nYoungest respondent is {resp.age_r.min()}')

#Pring oldest respondent
print(f'Oldest respondent is {resp.age_r.max()}')
# Out:
# 15    217
# 16    223
# 17    234
# 18    235
# 19    241
# 20    258
# 21    267
# 22    287
# 23    282
# 24    269
# 25    267
# 26    260
# 27    255
# 28    252
# 29    262
# 30    292
# 31    278
# 32    273
# 33    257
# 34    255
# 35    262
# 36    266
# 37    271
# 38    256
# 39    215
# 40    256
# 41    250
# 42    215
# 43    253
# 44    235
# Name: age_r, dtype: int64
#
# -----------------
# Youngest respondent is 15
# Oldest respondent is 44

# %% [markdown]
# We can use the caseid to match up rows from resp and preg. For example, we can select the row from resp for caseid 2298 like this:

# %%
resp[resp.caseid==2298]
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
#
#    age_r  cmbirth  agescrn  ...  pubassis_i      basewgt  adj_mod_basewgt  \
# 0     27      902       27  ...           0  3247.916977      5123.759559
#
#       finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime   intvlngth
# 0  5556.717241       2    18     1234     1222    18:26:36  110.492667
#
# [1 rows x 3087 columns]

# %%
# And we can get the corresponding rows from preg like this:
preg[preg.caseid==2298]
# Out:
#       caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 2610    2298         1        NaN        NaN       NaN       NaN       6.0
# 2611    2298         2        NaN        NaN       NaN       NaN       6.0
# 2612    2298         3        NaN        NaN       NaN       NaN       6.0
# 2613    2298         4        NaN        NaN       NaN       NaN       6.0
#
#       pregend2  nbrnaliv  multbrth  ...  religion_i  metro_i      basewgt  \
# 2610       NaN       1.0       NaN  ...           0        0  3247.916977
# 2611       NaN       1.0       NaN  ...           0        0  3247.916977
# 2612       NaN       1.0       NaN  ...           0        0  3247.916977
# 2613       NaN       1.0       NaN  ...           0        0  3247.916977
#
#       adj_mod_basewgt     finalwgt  secu_p  sest  cmintvw  totalwgt_lb  \
# 2610      5123.759559  5556.717241       2    18      NaN       6.8750
# 2611      5123.759559  5556.717241       2    18      NaN       5.5000
# ...

# %% [markdown]
# How old is the respondent with caseid 1?

# %%
#Filter the row with caseid == 1 and print the age
print(resp[resp.caseid==1].age_r)
print('The respondent with caseid 1 is 44 years old')
# Out:
# 1069    44
# Name: age_r, dtype: int64
# The respondent with caseid 1 is 44 years old

# %% [markdown]
# What are the pregnancy lengths for the respondent with caseid 2298?

# %%
#Filter the caseid 2298 and print her pregnancy lengths
preg[preg.caseid==2298].prglngth
# Out:
# 2610    40
# 2611    36
# 2612    30
# 2613    40
# Name: prglngth, dtype: int64

# %% [markdown]
# What was the birthweight of the first baby born to the respondent with caseid 5012?

# %%
#Filter the row for caseid 5012 and print the weight of first baby born.
#First born baby is identified by pregordr of 1. Filter on that field as well
preg[(preg.caseid==5012) & (preg.pregordr == 1)].birthwgt_lb
# preg[preg.caseid==5012].birthwgt_lb
# Caseid 5012 has only one row ( has only one birth) so it gives the same result if your filter by pregordr or not.
# Out:
# 5515    6.0
# Name: birthwgt_lb, dtype: float64

# %% [markdown]
# Make a dictionary that maps from each respondent's `caseid` to a list of indices into the pregnancy `DataFrame`.  Use it to select the pregnancy outcomes for a single respondent.

# %% [markdown]
# caseid = 10229
# preg_map = nsfg.MakePregMap(preg)
# indices = preg_map[caseid]
# preg.outcome[indices].values

# %% [markdown]
# ## Exercises 1.2

# %% [markdown]
# Write code that reads the respondent file, 2002FemResp.dat.gz. Cross-validate the respondent and pregnancy files by comparing pregnum for each respondent with the number of records in the pregnancy file.

# %%
import numpy as np

#Using packages written by the book author to read stata file and create Maps from dataframe to validate counts
import nsfg
import thinkstats2

#Using thinkstat2 module written by author read respondent stata file and convert it into data frame

respdct_file = '2002FemResp.dct'
respdat_file= '2002FemResp.dat.gz'
respdct = thinkstats2.ReadStataDct(respdct_file)
respdf = respdct.ReadFixedWidth(respdat_file, compression='gzip', nrows=None)

#Print value counts of the variable pregnum and compare results wtih NSFG codebook
print(respdf.pregnum.value_counts())

#Print pregnum as in NSFG codebook so that it's easy to compare
print(f'\n-----------------------\nNone {respdf[respdf.pregnum == 0].pregnum.count()}')
print(f'1 PREGNANCY {respdf[respdf.pregnum == 1].pregnum.count()}')
print(f'2 PREGNANCIES {respdf[respdf.pregnum == 2].pregnum.count()}')
print(f'3 PREGNANCIES {respdf[respdf.pregnum == 3].pregnum.count()}')
print(f'4 PREGNANCIES {respdf[respdf.pregnum == 4].pregnum.count()}')
print(f'5 PREGNANCIES {respdf[respdf.pregnum == 5].pregnum.count()}')
print(f'6 PREGNANCIES {respdf[respdf.pregnum == 6].pregnum.count()}')
print(f'7 OR MORE PREGNANCIES {respdf[respdf.pregnum >= 7].pregnum.count()}')


#Read pregnancy file using nsfg package method
pregdf = nsfg.ReadFemPreg()

# Create the map from caseid to list of pregnancy indices using method in nsfg package
preg_map = nsfg.MakePregMap(pregdf)

#Initialize a flag which we will use to confirm if recordset info matches
recordmatchFlag = True
#Now we iterate through respondent file pregnum series and if pregnum in respondent file does not match with 
#number of records in the pregnancy file, we break the loop and let the user know that something went wrong.
for index, pregnum in respdf.pregnum.items():
    caseid = respdf.caseid[index]
    indices = preg_map[caseid]
    #print(caseid, len(indices), pregnum)

    # check that pregnum from the respondent file equals
    # the number of records in the pregnancy file
    if len(indices) != pregnum:
        print(caseid, len(indices), pregnum)
        recordmatchFlag = False
        break
if recordmatchFlag:
    print("\nRecords matched between pregnancy and respondent datasets. Success")
else:
    print("\nRecords Mismatch between pregnancy and respondent datasets")
# Out:
# 0     2610
# 2     1432
# 1     1267
# 3     1110
# 4      611
# 5      305
# 6      150
# 7       80
# 8       40
# 9       21
# 10       9
# 11       3
# 14       2
# 12       2
# 19       1
# Name: pregnum, dtype: int64
#
# -----------------------
# None 2610
# 1 PREGNANCY 1267
# 2 PREGNANCIES 1432
# 3 PREGNANCIES 1110
# 4 PREGNANCIES 611
# 5 PREGNANCIES 305
# 6 PREGNANCIES 150
# 7 OR MORE PREGNANCIES 158
#
# Records matched between pregnancy and respondent datasets. Success

# %% [markdown]
# # Compare the result to the published results in NSFG codebook
# ![Pregnum.JPG](attachment:Pregnum.JPG)

# %% [markdown]
# ##### Based on results above and comparing that with NSFG codebook we find that Pregnancy counts match. We also find that there is match between number of pregnancies in respondent file and number of pregnancies deduced from pregnancy file.

# %% [markdown]
# ~~~------------------------------------------------------------------------------------------------~~~

# %% [markdown]
# ## Question 2 - 1
# #### Based on the results in this chapter, suppose you were asked to summarize what you learned about whether first babies arrive late. Which summary statistics would you use if you wanted to get story on the evening news? Which ones would you use if you wanted to reassure an anxious patient? Finally imaging that you are Cecil Adams, author of The Straight Dope, and your job is to answer the question, "Do first babies arrive late?" Write a paragraph that uses the results in this chapter to answer the question clearly, precisely and honestly.

# %% [markdown]
# To get information out in the evening news, I'll use frequency distribution of pregnancy length between two group, first babies and other babies. I'll also display histogram of these two group so that it's visually appealing in the news broadcast. Output below shows histogram.
# To reassure an anxious patient, I would use pregnancy length mean between first and other babies in addition to frequency distribution and histogram. Mean(s) calculated below.
# As Cecil Adams, if I have to answer "Do first babies arrive late?", I would answer, Why should they. They would come in the world when they are ready, it could be sooner than other babies or later. I would then provide pregnancy length mean between first and other babies and histogram to support the humor.

# %%
import thinkplot
#Using modules provided by the author
#Read female pregnancy file
preg = nsfg.ReadFemPreg()
#Capture only those pregnanies which were successful
live = preg[preg.outcome == 1]
#Group live pregnancies in two groups firsts and others
firsts = live[live.birthord == 1]
others = live[live.birthord != 1]

#Compute histogram using thinkstats2 package provided by the author
first_hist = thinkstats2.Hist(firsts.prglngth)
other_hist = thinkstats2.Hist(others.prglngth)

#Plot the histograms with 0.45 width and on same plane
width = 0.45
thinkplot.PrePlot(2)
thinkplot.Hist(first_hist, align='right', width=width, label="First")
thinkplot.Hist(other_hist, align='left', width=width, label = "Others")
thinkplot.Show(xlabel='weeks',ylabel='frequency')


print(f'\n Mean pregnancy length for first babies {firsts.prglngth.mean()}')
print(f'\n Mean pregnancy length for other babies {others.prglngth.mean()}')
# Out:
#  Mean pregnancy length for first babies 38.60095173351461
#
#  Mean pregnancy length for other babies 38.52291446673706

# %% [markdown]
# ~~~--------------------------------------------------------------------------~~~

# %% [markdown]
# ## Question 2 - 4
# #### Using the variable totalwgt_lb, investigate whether first babies are lighter or heavier than others. Compute Cohen's d to quantify the difference between the groups. How does it compare to the difference in pregnancy length?

# %% [markdown]
# We will use effect size summary statistic to answer this question. Mean weight of first babies is 7.20 lb and of other babies is 7.32 lbs, a difference of .12 lbs. This difference is insignificant for the purposes of clearly identifying if first babies are lighter or heavier.
# We will now calculate Cohen's d which compares the difference between groups to the variability within groups. For Cohen's d general rule of thumb is
# small effect = 0.2
# medium effect = 0.5
# large effect = 0.8
# In our calculation we find that cohen's d is .08 therefore it's small effect.

# %%
print(f'Mean weight of first born babies {firsts.totalwgt_lb.mean()}')
print(f'Mean weight of other babies {others.totalwgt_lb.mean()}')

diff_wt  = firsts.totalwgt_lb.mean() - others.totalwgt_lb.mean()
print(f'Difference in mean between first and other born babies {diff_wt}')
var1 = firsts.totalwgt_lb.var()
var2 = others.totalwgt_lb.var()
n1 = len(firsts.totalwgt_lb)
n2 = len(others.totalwgt_lb)
pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
d = diff_wt / np.sqrt(pooled_var)
print(f'Cohens d {d}')
# Out:
# Mean weight of first born babies 7.201094430437772
# Mean weight of other babies 7.325855614973262
# Difference in mean between first and other born babies -0.12476118453549034
# Cohens d -0.088672927072602
